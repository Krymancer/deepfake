# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import pickle
import os
import sys
from PIL import Image
import pandas as pd
import numpy as np
import seaborn as sns
import scipy
import keras
import tensorflow as tf
import cv2
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout 
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from sklearn.metrics import classification_report,confusion_matrix
from keras.models import Model as KerasModel
from keras.layers import Input, Dense, Flatten, Conv2D, MaxPooling2D, BatchNormalization, Dropout, Reshape, Concatenate, LeakyReLU
from tensorflow.keras.optimizers import Adam

# %%
directory = os.path.join('./data/dataset/')
img_height = 256
img_width = 256
batch_size = 32
nb_epochs = 100

print(directory)

train_datagen = ImageDataGenerator(rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2) # set validation split

train_generator = train_datagen.flow_from_directory(
    directory,
    follow_links=True,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',
    subset='training') # set as training data

validation_generator = train_datagen.flow_from_directory(
    directory, # same directory as training data
    follow_links=True,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',
    subset='validation') # set as validation data
# Out:
# ./data/dataset/
# Found 1600 images belonging to 2 classes.
# Found 400 images belonging to 2 classes.

# %%
learning_rate = 0.001

x = Input(shape = (img_width, img_height, 3))

x1 = Conv2D(8, (3, 3), padding='same', activation = 'relu')(x)
x1 = BatchNormalization()(x1)
x1 = MaxPooling2D(pool_size=(2, 2), padding='same')(x1)

x2 = Conv2D(8, (5, 5), padding='same', activation = 'relu')(x1)
x2 = BatchNormalization()(x2)
x2 = MaxPooling2D(pool_size=(2, 2), padding='same')(x2)

x3 = Conv2D(16, (5, 5), padding='same', activation = 'relu')(x2)
x3 = BatchNormalization()(x3)
x3 = MaxPooling2D(pool_size=(2, 2), padding='same')(x3)

x4 = Conv2D(16, (5, 5), padding='same', activation = 'relu')(x3)
x4 = BatchNormalization()(x4)
x4 = MaxPooling2D(pool_size=(4, 4), padding='same')(x4)

y = Flatten()(x4)
y = Dropout(0.5)(y)
y = Dense(16)(y)
y = LeakyReLU(alpha=0.1)(y)
y = Dropout(0.5)(y)
y = Dense(1, activation = 'sigmoid')(y)

model =  KerasModel(inputs = x, outputs = y)

optimizer = Adam(learning_rate = learning_rate)
model.compile(optimizer = optimizer, loss = 'mean_squared_error', metrics = ['accuracy'])

# %%
history = model.fit(
    train_generator,
    steps_per_epoch = train_generator.samples // batch_size,
    validation_data = validation_generator, 
    validation_steps = validation_generator.samples // batch_size,
    epochs = nb_epochs)
# Out:
# Epoch 1/100
# 50/50 [==============================] - 56s 1s/step - loss: 0.3018 - accuracy: 0.5638 - val_loss: 0.2586 - val_accuracy: 0.5547
# Epoch 2/100
# 50/50 [==============================] - 49s 985ms/step - loss: 0.2505 - accuracy: 0.6037 - val_loss: 0.3323 - val_accuracy: 0.5078
# Epoch 3/100
# 50/50 [==============================] - 49s 987ms/step - loss: 0.2444 - accuracy: 0.6250 - val_loss: 0.3527 - val_accuracy: 0.5130
# Epoch 4/100
# 50/50 [==============================] - 50s 987ms/step - loss: 0.2307 - accuracy: 0.6513 - val_loss: 0.3702 - val_accuracy: 0.4896
# Epoch 5/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.2199 - accuracy: 0.6750 - val_loss: 0.3405 - val_accuracy: 0.5000
# Epoch 6/100
# 50/50 [==============================] - 50s 1s/step - loss: 0.2215 - accuracy: 0.6750 - val_loss: 0.3031 - val_accuracy: 0.4557
# Epoch 7/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.2081 - accuracy: 0.6762 - val_loss: 0.2826 - val_accuracy: 0.4740
# Epoch 8/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.2039 - accuracy: 0.7025 - val_loss: 0.3047 - val_accuracy: 0.5078
# Epoch 9/100
# 50/50 [==============================] - 50s 987ms/step - loss: 0.2014 - accuracy: 0.7056 - val_loss: 0.3144 - val_accuracy: 0.5182
# Epoch 10/100
# 50/50 [==============================] - 50s 996ms/step - loss: 0.1929 - accuracy: 0.7237 - val_loss: 0.3116 - val_accuracy: 0.4271
# Epoch 11/100
# 50/50 [==============================] - 49s 982ms/step - loss: 0.1888 - accuracy: 0.7269 - val_loss: 0.3560 - val_accuracy: 0.4609
# Epoch 12/100
# 50/50 [==============================] - 49s 984ms/step - loss: 0.1932 - accuracy: 0.7125 - val_loss: 0.3148 - val_accuracy: 0.4948
# Epoch 13/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.1858 - accuracy: 0.7319 - val_loss: 0.3283 - val_accuracy: 0.4557
# Epoch 14/100
# 50/50 [==============================] - 52s 1s/step - loss: 0.1891 - accuracy: 0.7337 - val_loss: 0.3340 - val_accuracy: 0.4297
# Epoch 15/100
# 50/50 [==============================] - 50s 1s/step - loss: 0.1888 - accuracy: 0.7163 - val_loss: 0.3250 - val_accuracy: 0.5130
# Epoch 16/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.1728 - accuracy: 0.7519 - val_loss: 0.3433 - val_accuracy: 0.4818
# Epoch 17/100
# 50/50 [==============================] - 50s 995ms/step - loss: 0.1792 - accuracy: 0.7469 - val_loss: 0.3381 - val_accuracy: 0.4766
# Epoch 18/100
# 50/50 [==============================] - 50s 1s/step - loss: 0.1696 - accuracy: 0.7619 - val_loss: 0.3675 - val_accuracy: 0.3880
# Epoch 19/100
# 50/50 [==============================] - 50s 1s/step - loss: 0.1708 - accuracy: 0.7544 - val_loss: 0.3320 - val_accuracy: 0.4557
# Epoch 20/100
# 50/50 [==============================] - 50s 1s/step - loss: 0.1690 - accuracy: 0.7613 - val_loss: 0.3651 - val_accuracy: 0.4401
# Epoch 21/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.1745 - accuracy: 0.7500 - val_loss: 0.3338 - val_accuracy: 0.4297
# Epoch 22/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.1733 - accuracy: 0.7500 - val_loss: 0.3452 - val_accuracy: 0.4583
# Epoch 23/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.1682 - accuracy: 0.7550 - val_loss: 0.3287 - val_accuracy: 0.4661
# Epoch 24/100
# 50/50 [==============================] - 52s 1s/step - loss: 0.1713 - accuracy: 0.7619 - val_loss: 0.3854 - val_accuracy: 0.4036
# Epoch 25/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.1589 - accuracy: 0.7669 - val_loss: 0.3403 - val_accuracy: 0.4896
# Epoch 26/100
# 50/50 [==============================] - 50s 1s/step - loss: 0.1642 - accuracy: 0.7713 - val_loss: 0.4215 - val_accuracy: 0.3620
# Epoch 27/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.1632 - accuracy: 0.7694 - val_loss: 0.3628 - val_accuracy: 0.4427
# Epoch 28/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.1582 - accuracy: 0.7600 - val_loss: 0.3479 - val_accuracy: 0.4323
# Epoch 29/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.1588 - accuracy: 0.7800 - val_loss: 0.4010 - val_accuracy: 0.4141
# Epoch 30/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.1492 - accuracy: 0.7862 - val_loss: 0.4371 - val_accuracy: 0.4115
# Epoch 31/100
# 50/50 [==============================] - 52s 1s/step - loss: 0.1558 - accuracy: 0.7869 - val_loss: 0.3906 - val_accuracy: 0.4219
# Epoch 32/100
# 50/50 [==============================] - 50s 1s/step - loss: 0.1524 - accuracy: 0.7775 - val_loss: 0.3692 - val_accuracy: 0.4531
# Epoch 33/100
# 50/50 [==============================] - 49s 979ms/step - loss: 0.1502 - accuracy: 0.7881 - val_loss: 0.4231 - val_accuracy: 0.4141
# Epoch 34/100
# 50/50 [==============================] - 49s 983ms/step - loss: 0.1478 - accuracy: 0.7894 - val_loss: 0.3387 - val_accuracy: 0.4844
# Epoch 35/100
# 50/50 [==============================] - 49s 988ms/step - loss: 0.1542 - accuracy: 0.7750 - val_loss: 0.3990 - val_accuracy: 0.4141
# Epoch 36/100
# 50/50 [==============================] - 50s 995ms/step - loss: 0.1484 - accuracy: 0.7987 - val_loss: 0.3612 - val_accuracy: 0.4115
# Epoch 37/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.1455 - accuracy: 0.7994 - val_loss: 0.3701 - val_accuracy: 0.4635
# Epoch 38/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.1510 - accuracy: 0.7800 - val_loss: 0.3626 - val_accuracy: 0.4557
# Epoch 39/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.1440 - accuracy: 0.8031 - val_loss: 0.4031 - val_accuracy: 0.4505
# Epoch 40/100
# 50/50 [==============================] - 50s 990ms/step - loss: 0.1429 - accuracy: 0.7950 - val_loss: 0.4140 - val_accuracy: 0.4089
# Epoch 41/100
# 50/50 [==============================] - 50s 1s/step - loss: 0.1444 - accuracy: 0.8044 - val_loss: 0.4236 - val_accuracy: 0.4375
# Epoch 42/100
# 50/50 [==============================] - 50s 992ms/step - loss: 0.1319 - accuracy: 0.8188 - val_loss: 0.4126 - val_accuracy: 0.4036
# Epoch 43/100
# 50/50 [==============================] - 50s 1s/step - loss: 0.1294 - accuracy: 0.8238 - val_loss: 0.4249 - val_accuracy: 0.4531
# Epoch 44/100
# 50/50 [==============================] - 50s 1s/step - loss: 0.1375 - accuracy: 0.7987 - val_loss: 0.3846 - val_accuracy: 0.4661
# Epoch 45/100
# 50/50 [==============================] - 50s 1s/step - loss: 0.1389 - accuracy: 0.7975 - val_loss: 0.3757 - val_accuracy: 0.4219
# Epoch 46/100
# 50/50 [==============================] - 50s 997ms/step - loss: 0.1389 - accuracy: 0.8094 - val_loss: 0.3986 - val_accuracy: 0.4245
# Epoch 47/100
# 50/50 [==============================] - 50s 999ms/step - loss: 0.1255 - accuracy: 0.8238 - val_loss: 0.4486 - val_accuracy: 0.4089
# Epoch 48/100
# 50/50 [==============================] - 50s 1s/step - loss: 0.1416 - accuracy: 0.8081 - val_loss: 0.3755 - val_accuracy: 0.4505
# Epoch 49/100
# 50/50 [==============================] - 50s 994ms/step - loss: 0.1270 - accuracy: 0.8225 - val_loss: 0.4068 - val_accuracy: 0.3932
# Epoch 50/100
# 50/50 [==============================] - 50s 1s/step - loss: 0.1282 - accuracy: 0.8188 - val_loss: 0.4102 - val_accuracy: 0.4193
# Epoch 51/100
# 50/50 [==============================] - 50s 993ms/step - loss: 0.1301 - accuracy: 0.8219 - val_loss: 0.3721 - val_accuracy: 0.5000
# Epoch 52/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.1350 - accuracy: 0.8169 - val_loss: 0.4552 - val_accuracy: 0.4089
# Epoch 53/100
# 50/50 [==============================] - 50s 1s/step - loss: 0.1213 - accuracy: 0.8313 - val_loss: 0.4245 - val_accuracy: 0.4167
# Epoch 54/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.1227 - accuracy: 0.8200 - val_loss: 0.4314 - val_accuracy: 0.4245
# Epoch 55/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.1161 - accuracy: 0.8344 - val_loss: 0.4412 - val_accuracy: 0.4089
# Epoch 56/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.1214 - accuracy: 0.8281 - val_loss: 0.4539 - val_accuracy: 0.4036
# Epoch 57/100
# 50/50 [==============================] - 50s 1s/step - loss: 0.1190 - accuracy: 0.8319 - val_loss: 0.4631 - val_accuracy: 0.4141
# Epoch 58/100
# 50/50 [==============================] - 50s 1s/step - loss: 0.1184 - accuracy: 0.8350 - val_loss: 0.4507 - val_accuracy: 0.4219
# Epoch 59/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.1201 - accuracy: 0.8325 - val_loss: 0.3913 - val_accuracy: 0.4505
# Epoch 60/100
# 50/50 [==============================] - 52s 1s/step - loss: 0.1146 - accuracy: 0.8338 - val_loss: 0.3765 - val_accuracy: 0.4557
# Epoch 61/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.1256 - accuracy: 0.8219 - val_loss: 0.4082 - val_accuracy: 0.4609
# Epoch 62/100
# 50/50 [==============================] - 50s 1s/step - loss: 0.1191 - accuracy: 0.8294 - val_loss: 0.4091 - val_accuracy: 0.4453
# Epoch 63/100
# 50/50 [==============================] - 50s 1s/step - loss: 0.1202 - accuracy: 0.8350 - val_loss: 0.4228 - val_accuracy: 0.3984
# Epoch 64/100
# 50/50 [==============================] - 50s 1s/step - loss: 0.1156 - accuracy: 0.8481 - val_loss: 0.4500 - val_accuracy: 0.4349
# Epoch 65/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.1169 - accuracy: 0.8288 - val_loss: 0.4005 - val_accuracy: 0.5000
# Epoch 66/100
# 50/50 [==============================] - 50s 997ms/step - loss: 0.1075 - accuracy: 0.8550 - val_loss: 0.4296 - val_accuracy: 0.4167
# Epoch 67/100
# 50/50 [==============================] - 50s 991ms/step - loss: 0.1096 - accuracy: 0.8550 - val_loss: 0.4292 - val_accuracy: 0.4219
# Epoch 68/100
# 50/50 [==============================] - 50s 1s/step - loss: 0.1154 - accuracy: 0.8388 - val_loss: 0.4207 - val_accuracy: 0.4427
# Epoch 69/100
# 50/50 [==============================] - 50s 1s/step - loss: 0.1126 - accuracy: 0.8450 - val_loss: 0.4226 - val_accuracy: 0.4349
# Epoch 70/100
# 50/50 [==============================] - 50s 999ms/step - loss: 0.1158 - accuracy: 0.8425 - val_loss: 0.3963 - val_accuracy: 0.4505
# Epoch 71/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.1129 - accuracy: 0.8475 - val_loss: 0.3946 - val_accuracy: 0.4714
# Epoch 72/100
# 50/50 [==============================] - 50s 998ms/step - loss: 0.1097 - accuracy: 0.8456 - val_loss: 0.4387 - val_accuracy: 0.4219
# Epoch 73/100
# 50/50 [==============================] - 50s 1s/step - loss: 0.1155 - accuracy: 0.8325 - val_loss: 0.4430 - val_accuracy: 0.4010
# Epoch 74/100
# 50/50 [==============================] - 50s 1s/step - loss: 0.1073 - accuracy: 0.8519 - val_loss: 0.3785 - val_accuracy: 0.4896
# Epoch 75/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.1000 - accuracy: 0.8625 - val_loss: 0.4399 - val_accuracy: 0.4349
# Epoch 76/100
# 50/50 [==============================] - 50s 1s/step - loss: 0.1082 - accuracy: 0.8569 - val_loss: 0.4214 - val_accuracy: 0.4479
# Epoch 77/100
# 50/50 [==============================] - 50s 1s/step - loss: 0.1015 - accuracy: 0.8612 - val_loss: 0.3738 - val_accuracy: 0.5339
# Epoch 78/100
# 50/50 [==============================] - 50s 988ms/step - loss: 0.1093 - accuracy: 0.8413 - val_loss: 0.4303 - val_accuracy: 0.4375
# Epoch 79/100
# 50/50 [==============================] - 50s 998ms/step - loss: 0.1017 - accuracy: 0.8631 - val_loss: 0.4619 - val_accuracy: 0.4245
# Epoch 80/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.1021 - accuracy: 0.8487 - val_loss: 0.4265 - val_accuracy: 0.4245
# Epoch 81/100
# 50/50 [==============================] - 50s 991ms/step - loss: 0.1031 - accuracy: 0.8550 - val_loss: 0.4054 - val_accuracy: 0.4896
# Epoch 82/100
# 50/50 [==============================] - 49s 984ms/step - loss: 0.1033 - accuracy: 0.8606 - val_loss: 0.4451 - val_accuracy: 0.4167
# Epoch 83/100
# 50/50 [==============================] - 50s 989ms/step - loss: 0.0999 - accuracy: 0.8562 - val_loss: 0.4244 - val_accuracy: 0.4479
# Epoch 84/100
# 50/50 [==============================] - 50s 1s/step - loss: 0.0998 - accuracy: 0.8637 - val_loss: 0.4256 - val_accuracy: 0.4349
# Epoch 85/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.1042 - accuracy: 0.8494 - val_loss: 0.4308 - val_accuracy: 0.4375
# Epoch 86/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.0935 - accuracy: 0.8781 - val_loss: 0.3839 - val_accuracy: 0.5000
# Epoch 87/100
# 50/50 [==============================] - 50s 1s/step - loss: 0.0993 - accuracy: 0.8637 - val_loss: 0.4083 - val_accuracy: 0.4557
# Epoch 88/100
# 50/50 [==============================] - 49s 990ms/step - loss: 0.0958 - accuracy: 0.8594 - val_loss: 0.4457 - val_accuracy: 0.4505
# Epoch 89/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.1075 - accuracy: 0.8487 - val_loss: 0.4103 - val_accuracy: 0.4740
# Epoch 90/100
# 50/50 [==============================] - 52s 1s/step - loss: 0.0956 - accuracy: 0.8675 - val_loss: 0.3863 - val_accuracy: 0.5000
# Epoch 91/100
# 50/50 [==============================] - 49s 985ms/step - loss: 0.1076 - accuracy: 0.8450 - val_loss: 0.4156 - val_accuracy: 0.4505
# Epoch 92/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.0862 - accuracy: 0.8863 - val_loss: 0.4448 - val_accuracy: 0.4193
# Epoch 93/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.0963 - accuracy: 0.8706 - val_loss: 0.4236 - val_accuracy: 0.4479
# Epoch 94/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.0935 - accuracy: 0.8675 - val_loss: 0.4001 - val_accuracy: 0.4557
# Epoch 95/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.0940 - accuracy: 0.8594 - val_loss: 0.4701 - val_accuracy: 0.3854
# Epoch 96/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.0971 - accuracy: 0.8763 - val_loss: 0.4696 - val_accuracy: 0.4297
# Epoch 97/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.0889 - accuracy: 0.8731 - val_loss: 0.4456 - val_accuracy: 0.4219
# Epoch 98/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.0937 - accuracy: 0.8731 - val_loss: 0.4432 - val_accuracy: 0.4245
# Epoch 99/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.0868 - accuracy: 0.8775 - val_loss: 0.4151 - val_accuracy: 0.4922
# Epoch 100/100
# 50/50 [==============================] - 51s 1s/step - loss: 0.0953 - accuracy: 0.8712 - val_loss: 0.4507 - val_accuracy: 0.4323

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(nb_epochs)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
max_acc = max(acc)
mean_acc = np.mean(acc)

max_validation = max(val_acc)
mean_validation = np.mean(val_acc)

max_loss = max(loss)
mean_loss = np.mean(loss)

max_loss_validation = max(val_loss)
mean_loss_validation = np.mean(val_loss)

print('Max accuracy test:', max_acc)
print('Max accuracy test epoch:', acc.index(max_acc))
print('Mean accuracy test:', mean_acc)
print('Max accuracy validation:', max_validation)
print('Max accuracy validation epoch:', val_acc.index(max_validation))
print('Mean accuracy validation:', mean_validation)
print('Max loss test:', max_loss)
print('Max loss test epoch:', loss.index(max_loss))
print('Mean loss test:', mean_loss)
print('Max loss validation:', max_loss_validation)
# Out:
# Max accuracy test: 0.8862500190734863
# Max accuracy test epoch: 91
# Mean accuracy test: 0.8016750007867813
# Max accuracy validation: 0.5546875
# Max accuracy validation epoch: 0
# Mean accuracy validation: 0.4467447915673256
# Max loss test: 0.30184096097946167
# Max loss test epoch: 0
# Mean loss test: 0.13944259956479071
# Max loss validation: 0.47012415528297424
