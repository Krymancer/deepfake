# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import pickle
import os
import sys
from PIL import Image
import pandas as pd
import numpy as np
import seaborn as sns
import scipy
import keras
import tensorflow as tf
import cv2
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout 
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from sklearn.metrics import classification_report,confusion_matrix
from keras.models import Model as KerasModel
from keras.layers import Input, Dense, Flatten, Conv2D, MaxPooling2D, BatchNormalization, Dropout, Reshape, Concatenate, LeakyReLU
from tensorflow.keras.optimizers import Adam

# %%
directory = os.path.join('./data/face_extraction/')
img_height = 32
img_width = 32
batch_size = 32
nb_epochs = 100

print(directory)

train_datagen = ImageDataGenerator(rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2) # set validation split

train_generator = train_datagen.flow_from_directory(
    directory,
    follow_links=True,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',
    subset='training') # set as training data

validation_generator = train_datagen.flow_from_directory(
    directory, # same directory as training data
    follow_links=True,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',
    subset='validation') # set as validation data
# Out:
# ./data/face_extraction/
# Found 1592 images belonging to 2 classes.
# Found 397 images belonging to 2 classes.

# %%
learning_rate = 0.001

x = Input(shape = (img_width, img_height, 3))

x1 = Conv2D(8, (3, 3), padding='same', activation = 'relu')(x)
x1 = BatchNormalization()(x1)
x1 = MaxPooling2D(pool_size=(2, 2), padding='same')(x1)

x2 = Conv2D(8, (5, 5), padding='same', activation = 'relu')(x1)
x2 = BatchNormalization()(x2)
x2 = MaxPooling2D(pool_size=(2, 2), padding='same')(x2)

x3 = Conv2D(16, (5, 5), padding='same', activation = 'relu')(x2)
x3 = BatchNormalization()(x3)
x3 = MaxPooling2D(pool_size=(2, 2), padding='same')(x3)

x4 = Conv2D(16, (5, 5), padding='same', activation = 'relu')(x3)
x4 = BatchNormalization()(x4)
x4 = MaxPooling2D(pool_size=(4, 4), padding='same')(x4)

y = Flatten()(x4)
y = Dropout(0.5)(y)
y = Dense(16)(y)
y = LeakyReLU(alpha=0.1)(y)
y = Dropout(0.5)(y)
y = Dense(1, activation = 'sigmoid')(y)

model =  KerasModel(inputs = x, outputs = y)

optimizer = Adam(learning_rate = learning_rate)
model.compile(optimizer = optimizer, loss = 'mean_squared_error', metrics = ['accuracy'])

# %%
history = model.fit(
    train_generator,
    steps_per_epoch = train_generator.samples // batch_size,
    validation_data = validation_generator, 
    validation_steps = validation_generator.samples // batch_size,
    epochs = nb_epochs)
# Out:
# Epoch 1/100
# 49/49 [==============================] - 7s 117ms/step - loss: 0.3371 - accuracy: 0.5487 - val_loss: 0.2533 - val_accuracy: 0.5000
# Epoch 2/100
# 49/49 [==============================] - 4s 75ms/step - loss: 0.2872 - accuracy: 0.5615 - val_loss: 0.2668 - val_accuracy: 0.5000
# Epoch 3/100
# 49/49 [==============================] - 4s 77ms/step - loss: 0.2662 - accuracy: 0.6129 - val_loss: 0.2919 - val_accuracy: 0.5000
# Epoch 4/100
# 49/49 [==============================] - 4s 75ms/step - loss: 0.2445 - accuracy: 0.6256 - val_loss: 0.3045 - val_accuracy: 0.5104
# Epoch 5/100
# 49/49 [==============================] - 4s 77ms/step - loss: 0.2418 - accuracy: 0.6417 - val_loss: 0.3346 - val_accuracy: 0.5052
# Epoch 6/100
# 49/49 [==============================] - 4s 75ms/step - loss: 0.2300 - accuracy: 0.6365 - val_loss: 0.3484 - val_accuracy: 0.4948
# Epoch 7/100
# 49/49 [==============================] - 4s 76ms/step - loss: 0.2194 - accuracy: 0.6821 - val_loss: 0.3567 - val_accuracy: 0.5052
# Epoch 8/100
# 49/49 [==============================] - 4s 79ms/step - loss: 0.2207 - accuracy: 0.6660 - val_loss: 0.3724 - val_accuracy: 0.5052
# Epoch 9/100
# 49/49 [==============================] - 4s 76ms/step - loss: 0.2199 - accuracy: 0.6705 - val_loss: 0.2901 - val_accuracy: 0.5443
# Epoch 10/100
# 49/49 [==============================] - 5s 96ms/step - loss: 0.2086 - accuracy: 0.7071 - val_loss: 0.3688 - val_accuracy: 0.5182
# Epoch 11/100
# 49/49 [==============================] - 4s 74ms/step - loss: 0.2071 - accuracy: 0.6782 - val_loss: 0.2726 - val_accuracy: 0.5026
# Epoch 12/100
# 49/49 [==============================] - 4s 72ms/step - loss: 0.2055 - accuracy: 0.7019 - val_loss: 0.2867 - val_accuracy: 0.5651
# Epoch 13/100
# 49/49 [==============================] - 4s 76ms/step - loss: 0.1979 - accuracy: 0.7103 - val_loss: 0.2756 - val_accuracy: 0.5391
# Epoch 14/100
# 49/49 [==============================] - 4s 74ms/step - loss: 0.1965 - accuracy: 0.7147 - val_loss: 0.2769 - val_accuracy: 0.5703
# Epoch 15/100
# 49/49 [==============================] - 4s 77ms/step - loss: 0.1983 - accuracy: 0.7045 - val_loss: 0.2564 - val_accuracy: 0.5729
# Epoch 16/100
# 49/49 [==============================] - 4s 74ms/step - loss: 0.
100
# 49/49 [==============================] - 4s 77ms/step - loss: 0.1061 - accuracy: 0.8603 - val_loss: 0.2961 - val_accuracy: 0.5911
# Epoch 75/100
# 49/49 [==============================] - 4s 78ms/step - loss: 0.1193 - accuracy: 0.8378 - val_loss: 0.3795 - val_accuracy: 0.5000
# Epoch 76/100
# 49/49 [==============================] - 4s 78ms/step - loss: 0.1155 - accuracy: 0.8481 - val_loss: 0.3393 - val_accuracy: 0.5234
# Epoch 77/100
# 49/49 [==============================] - 4s 78ms/step - loss: 0.1170 - accuracy: 0.8506 - val_loss: 0.3760 - val_accuracy: 0.5286
# Epoch 78/100
# 49/49 [==============================] - 4s 81ms/step - loss: 0.1152 - accuracy: 0.8449 - val_loss: 0.3342 - val_accuracy: 0.5729
# Epoch 79/100
# 49/49 [==============================] - 4s 76ms/step - loss: 0.1031 - accuracy: 0.8590 - val_loss: 0.3335 - val_accuracy: 0.5703
# Epoch 80/100
# 49/49 [==============================] - 4s 74ms/step - loss: 0.1176 - accuracy: 0.8455 - val_loss: 0.2933 - val_accuracy: 0.5781
# Epoch 81/100
# 49/49 [==============================] - 4s 77ms/step - loss: 0.1079 - accuracy: 0.8622 - val_loss: 0.3581 - val_accuracy: 0.5651
# Epoch 82/100
# 49/49 [==============================] - 4s 77ms/step - loss: 0.1099 - accuracy: 0.8513 - val_loss: 0.3403 - val_accuracy: 0.5443
# Epoch 83/100
# 49/49 [==============================] - 4s 76ms/step - loss: 0.1106 - accuracy: 0.8481 - val_loss: 0.3666 - val_accuracy: 0.5286
# Epoch 84/100
# 49/49 [==============================] - 4s 76ms/step - loss: 0.1216 - accuracy: 0.8365 - val_loss: 0.3324 - val_accuracy: 0.5547
# Epoch 85/100
# 49/49 [==============================] - 4s 77ms/step - loss: 0.1034 - accuracy: 0.8564 - val_loss: 0.3716 - val_accuracy: 0.5182
# Epoch 86/100
# 49/49 [==============================] - 4s 75ms/step - loss: 0.1022 - accuracy: 0.8647 - val_loss: 0.3583 - val_accuracy: 0.5260
# Epoch 87/100
# 49/49 [==============================] - 4s 75ms/step - loss: 0.1091 - accuracy: 0.8603 - val_loss: 0.3396 - val_accuracy: 0.5495
# Epoch 88/100
# 49/49 [==============================] - 4s 80ms/step - loss: 0.1098 - accuracy: 0.8545 - val_loss: 0.3342 - val_accuracy: 0.5573
# Epoch 89/100
# 49/49 [==============================] - 4s 76ms/step - loss: 0.0973 - accuracy: 0.8788 - val_loss: 0.3658 - val_accuracy: 0.5312
# Epoch 90/100
# 49/49 [==============================] - 4s 76ms/step - loss: 0.0939 - accuracy: 0.8763 - val_loss: 0.3681 - val_accuracy: 0.5391
# Epoch 91/100
# 49/49 [==============================] - 4s 76ms/step - loss: 0.1140 - accuracy: 0.8533 - val_loss: 0.3609 - val_accuracy: 0.5443
# Epoch 92/100
# 49/49 [==============================] - 4s 75ms/step - loss: 0.0988 - accuracy: 0.8692 - val_loss: 0.3515 - val_accuracy: 0.5417
# Epoch 93/100
# 49/49 [==============================] - 4s 76ms/step - loss: 0.0953 - accuracy: 0.8705 - val_loss: 0.3999 - val_accuracy: 0.5130
# Epoch 94/100
# 49/49 [==============================] - 4s 75ms/step - loss: 0.0904 - accuracy: 0.8840 - val_loss: 0.3390 - val_accuracy: 0.5677
# Epoch 95/100
# 49/49 [==============================] - 4s 79ms/step - loss: 0.1010 - accuracy: 0.8744 - val_loss: 0.3620 - val_accuracy: 0.5391
# Epoch 96/100
# 49/49 [==============================] - 4s 77ms/step - loss: 0.1058 - accuracy: 0.8609 - val_loss: 0.3530 - val_accuracy: 0.5417
# Epoch 97/100
# 49/49 [==============================] - 4s 76ms/step - loss: 0.1071 - accuracy: 0.8564 - val_loss: 0.3840 - val_accuracy: 0.5104
# Epoch 98/100
# 49/49 [==============================] - 4s 78ms/step - loss: 0.1058 - accuracy: 0.8577 - val_loss: 0.3978 - val_accuracy: 0.5286
# Epoch 99/100
# 49/49 [==============================] - 4s 77ms/step - loss: 0.1022 - accuracy: 0.8590 - val_loss: 0.3616 - val_accuracy: 0.5573
# Epoch 100/100
# 49/49 [==============================] - 4s 77ms/step - loss: 0.0945 - accuracy: 0.8750 - val_loss: 0.2820 - val_accuracy: 0.6328

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(nb_epochs)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
acc = history.history['accuracy']
max_acc = max(acc)
print('Max accuracy:', max_acc)
print('Max accuracy epoch:', acc.index(max_acc))

mean_acc = np.mean(acc)
print('Mean accuracy:', mean_acc)
# Out:
# Max accuracy: 0.8839743733406067
# Max accuracy epoch: 93
# Mean accuracy: 0.7919454479217529
